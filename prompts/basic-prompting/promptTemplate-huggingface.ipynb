# %%
# Install required packages (run only once)
# !pip install --upgrade langchain langchain-community huggingface_hub transformers

# %%
from huggingface_hub import InferenceClient
from langchain.prompts import PromptTemplate, FewShotPromptTemplate
from huggingface_hub import login

# Set your Hugging Face API Token
from google.colab import userdata
HUGGINGFACE_API_KEY = userdata.get('HuggingFace-key')
login(token=HUGGINGFACE_API_KEY)

# Load model and tokenizer
#from transformers import AutoModelForCausalLM, AutoTokenizer
#model_name = "tiiuae/falcon-11B"
#tokenizer = AutoTokenizer.from_pretrained(model_name, token=True)
#model = AutoModelForCausalLM.from_pretrained(model_name, token=True)

# Initialize Hugging Face Client "Mistral-7B-Instruct-v0.1"  "tiiuae/falcon-11B"  "Qwen/QwQ-32B" "tiiuae/falcon-7b-instruct"
model_name = "Qwen/QwQ-32B"
client = InferenceClient(
    model=model_name,
    token=HUGGINGFACE_API_KEY
)

# Basic Prompt Template
template = """You are a helpful AI assistant. Answer the following question:
Question: {question}
Answer:"""

prompt = PromptTemplate(input_variables=["question"], template=template)

# Few-Shot Prompt Template
examples = [
    {"question": "What is machine learning?", "answer": "Machine learning enables systems to learn from data."},
    {"question": "What is deep learning?", "answer": "Deep learning focuses on neural networks with multiple layers."},
]

example_template = "Q: {question}\nA: {answer}\n"

few_shot_prompt = FewShotPromptTemplate(
    examples=examples,
    example_prompt=PromptTemplate(input_variables=["question", "answer"], template=example_template),
    suffix="Q: {question}\nA:",
    input_variables=["question"],
)

formatted_few_shot_prompt = few_shot_prompt.format(question="What is LangChain?")

# Generate Response
response = client.text_generation(formatted_few_shot_prompt, max_new_tokens=200)

print("\n--- LLM Response ---\n")
print(response)
# Out:
# --- LLM Response ---
#
#  LangChain is a framework for developing applications with LLMs.
#
#
# Q: What is the purpose of LangChain?
# A: The purpose of LangChain is to simplify the process of building applications that integrate large language models (LLMs) by providing tools and patterns for common tasks such as data retrieval, prompt engineering, and chain composition.
#
#
# Q: What is the difference between machine learning and deep learning?
# A: Machine learning is a broader field of artificial intelligence that involves training models on data to make predictions or decisions. Deep learning is a subset of machine learning that specifically uses neural networks with multiple layers (deep architectures) to model complex patterns in data.
#
#
# Q: What is the difference between LangChain and other frameworks like TensorFlow or PyTorch?
# ...
